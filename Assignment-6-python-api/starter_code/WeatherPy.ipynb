# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

num_cities = 500

# Create a set of random lat and lng combinations

#changed this to a while loop to get 500 cities.
# while len(cities)<num_cities:
#     lat = np.random.uniform(low=-90.000, high=90.000)
#     lng = np.random.uniform(low=-180.000, high=180.000)
#     #lat_lngs = zip(lats, lngs)

#     # Identify nearest city for each lat, lng combination
#     city = citipy.nearest_city(lat, lng).city_name
    
#     # If the city is unique, then add it to our cities list
#     if city not in cities:
#         cities.append(city)

# # Print the city count to confirm sufficient count
# len(cities)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
owm_url = f'http://api.openweathermap.org/data/2.5/weather?APPID={api_key}&q='

#print(json.dumps(requests.get(owm_url+cities[7]).json(),indent=4))
city_jsons = []
print("Beginning Data Retrieval\n------------------------")
# for i in range(len(cities)):
#     city_json = requests.get(owm_url+cities[i]).json()
#     if city_json['cod'] == 200:
#         print(f"Processing Record {i} of {num_cities} | {city_json['name']} ")
#         city_jsons.append(city_json)
#     else:
#         print(f"{cities[i]} not found, skipping")


#combining the create city list and fetch data steps to make it easier to make sure to get 500 unique cities that are available
#in OWM.

i = 1             
while len(city_jsons) < num_cities:
    lat = np.random.uniform(low=-90.000, high=90.000)
    lng = np.random.uniform(low=-180.000, high=180.000)
    city = citipy.nearest_city(lat, lng).city_name
    if city not in cities:
        cities.append(city)
        city_json = requests.get(owm_url+city).json()
        if city_json['cod'] == 200: #success response
            print(f"Processing Record {i} of {num_cities} | {city_json['name']} ")
            city_jsons.append(city_json)
            i += 1
        else:
            print(f"{city} not found, retrying")
    else:
        print(f"Repeat city, retrying")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of 500 | Launceston
# Processing Record 2 of 500 | Puerto Ayora
# Processing Record 3 of 500 | Saldanha
# attawapiskat not found, retrying
# Processing Record 4 of 500 | Jamestown
# Processing Record 5 of 500 | Victoria
# Processing Record 6 of 500 | Vaini
# Processing Record 7 of 500 | Albany
# mooi river not found, retrying
# Processing Record 8 of 500 | Bandar
# Processing Record 9 of 500 | Pedernales
# Processing Record 10 of 500 | Mataura
# Processing Record 11 of 500 | Narsaq
# Processing Record 12 of 500 | Dikson
# Processing Record 13 of 500 | Luena
# Processing Record 14 of 500 | Thompson
# Processing Record 15 of 500 | Busselton
# Processing Record 16 of 500 | Goderich
# Processing Record 17 of 500 | Karratha
# Processing Record 18 of 500 | Kandrian
# Processing Record 19 of 500 | Jinchang
# Processing Record 20 of 500 | Hermanus
# Processing Record 21 of 500 | Gwadar
# Processing Record 22 of 500 | La Ronge
# Repeat city, retrying
# Processing Record 23 of 500 | Interlaken
# Repeat city, retrying
# Processing Record 24 of 500 | Ayan
# Processing Record 25 of 500 | Tasiilaq
# Processing Record 26 of 500 | Ushuaia
# Processing Record 27 of 500 | Sarangani
# Processing Record 28 of 500 | Vestmannaeyjar
# Processing Record 29 of 500 | Norman Wells
# Repeat city, retrying
# Processing Record 30 of 500 | Lagoa
# Processing Record 31 of 500 | Upernavik
# Processing Record 32 of 500 | Hilo
# Processing Record 33 of 500 | Pevek
# Repeat city, retrying
# Processing Record 34 of 500 | Katsuura
# Processing Record 35 of 500 | Guangyuan
# Processing Record 36 of 500 | Chivay
# Processing Record 37 of 500 | Atuona
# Processing Record 38 of 500 | Buldana
# Processing Record 39 of 500 | Denpasar
# lolua not found, retrying
# Processing Record 40 of 500 | Bredasdorp
# Processing Record 41 of 500 | Bhadasar
# Processing Record 42 of 500 | Teahupoo
# Processing Record 43 of 500 | Bacolod
# Processing Record 44 of 500 | Lubango
# Processing Record 45 of 500 | Ola
# Processing Record 46 of 500 | Jalu
# samusu not found, retrying
# Processing Record 47 of 500 | Saquarema
# tumannyy not found, retrying
# Processing Record 48 of 500 | Clifton
# Processing Record 49 of 500 | Kapaa
# Repeat city, retrying
# Processing Record 50 of 500 | Husavik
# Processing Record 51 of 500 | Guerrero Negro
# Processing Record 52 of 500 | Laguna
# Processing Record 53 of 500 | Bluff
# Repeat city, retrying
# Processing Record 54 of 500 | Sorland
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 55 of 500 | Reconquista
# Processing Record 56 of 500 | Qaanaaq
# Processing Record 57 of 500 | Arman
# Repeat city, retrying
# Processing Record 58 of 500 | Saint-Augustin
# Processing Record 59 of 500 | Robertsport
# Processing Record 60 of 500 | Nanortalik
# Processing Record 61 of 500 | Okha
# Repeat city, retrying
# Repeat city, retrying
# amderma not found, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 62 of 500 | Port Augusta
# Processing Record 63 of 500 | Lufilufi
# Repeat city, retrying
# Processing Record 64 of 500 | Port Alfred
# umzimvubu not found, retrying
# Repeat city, retrying
# Processing Record 65 of 500 | Dullewala
# Processing Record 66 of 500 | Lata
# Processing Record 67 of 500 | Durango
# taolanaro not found, retrying
# Processing Record 68 of 500 | Port Lincoln
# Processing Record 69 of 500 | Yanam
# Repeat city, retrying
# Processing Record 70 of 500 | Bedford
# Processing Record 71 of 500 | Talnakh
# Processing Record 72 of 500 | Kodiak
# Processing Record 73 of 500 | Ilulissat
# Processing Record 74 of 500 | Jovellar
# Processing Record 75 of 500 | East London
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 76 of 500 | Nyurba
# Repeat city, retrying
# temaraia not found, retrying
# Processing Record 77 of 500 | Cape Town
# Repeat city, retrying
# Processing Record 78 of 500 | Torbay
# Repeat city, retrying
# Processing Record 79 of 500 | Rikitea
# Processing Record 80 of 500 | Tuktoyaktuk
# Processing Record 81 of 500 | Chabahar
# Processing Record 82 of 500 | Esmeraldas
# Processing Record 83 of 500 | Oyama
# Repeat city, retrying
# Repeat city, retrying
# burica not found, retrying
# Processing Record 84 of 500 | Punta Arenas
# jiddah not found, retrying
# Processing Record 85 of 500 | Gander
# Repeat city, retrying
# Processing Record 86 of 500 | Adrar
# Processing Record 87 of 500 | Barra do Corda
# Repeat city, retrying
# sentyabrskiy not found, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 88 of 500 | Namibe
# Processing Record 89 of 500 | Haines Junction
# Processing Record 90 of 500 | New Norfolk
# Processing Record 91 of 500 | Pryozerne
# Processing Record 92 of 500 | Iqaluit
# Processing Record 93 of 500 | Tateyama
# Processing Record 94 of 500 | Cherskiy
# Processing Record 95 of 500 | Cabo San Lucas
# Processing Record 96 of 500 | Constitucion
# Processing Record 97 of 500 | Kruisfontein
# Repeat city, retrying
# Processing Record 98 of 500 | Alta Floresta
# Repeat city, retrying
# Processing Record 99 of 500 | Viedma
# Repeat city, retrying
# Processing Record 100 of 500 | Minot
# Processing Record 101 of 500 | Dingle
# Processing Record 102 of 500 | Lebu
# palabuhanratu not found, retrying
# Processing Record 103 of 500 | Calderitas
# Processing Record 104 of 500 | Tubuala
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 105 of 500 | Yellowknife
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 106 of 500 | Ngunguru
# Processing Record 107 of 500 | Ugoofaaru
# kuche not found, retrying
# Processing Record 108 of 500 | Inirida
# Processing Record 109 of 500 | Sao Filipe
# Processing Record 110 of 500 | Inhambane
# Processing Record 111 of 500 | Kletskaya
# Processing Record 112 of 500 | Saint-Philippe
# Processing Record 113 of 500 | Rome
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 114 of 500 | Barrow
# Processing Record 115 of 500 | Komsomolskiy
# Processing Record 116 of 500 | Ust-Kuyga
# Repeat city, retrying
# Processing Record 117 of 500 | Faya
# Processing Record 118 of 500 | Butaritari
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 119 of 500 | Bollnas
# Processing Record 120 of 500 | Nicoya
# Processing Record 121 of 500 | Souillac
# Processing Record 122 of 500 | Dali
# Processing Record 123 of 500 | Fez
# Processing Record 124 of 500 | Esperance
# Repeat city, retrying
# Processing Record 125 of 500 | Navirai
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 126 of 500 | Hami
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 127 of 500 | Nabire
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 128 of 500 | Hay River
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 129 of 500 | Kaitangata
# Processing Record 130 of 500 | Severo-Kurilsk
# Processing Record 131 of 500 | Bethel
# Repeat city, retrying
# Processing Record 132 of 500 | Nacala
# Processing Record 133 of 500 | Port Elizabeth
# Processing Record 134 of 500 | Kavieng
# Processing Record 135 of 500 | Raudeberg
# Processing Record 136 of 500 | Mahibadhoo
# Processing Record 137 of 500 | Vila Velha
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 138 of 500 | Hobyo
# Processing Record 139 of 500 | Tuatapere
# Processing Record 140 of 500 | Ponta do Sol
# kazalinsk not found, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 141 of 500 | Orlik
# Processing Record 142 of 500 | Nome
# Repeat city, retrying
# Processing Record 143 of 500 | Provideniya
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 144 of 500 | Shangrao
# Processing Record 145 of 500 | Cookeville
# Processing Record 146 of 500 | Virginia Beach
# Repeat city, retrying
# Processing Record 147 of 500 | San Andres
# Processing Record 148 of 500 | Shenzhen
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 149 of 500 | Ribeira Grande
# Repeat city, retrying
# Processing Record 150 of 500 | Mar del Plata
# Processing Record 151 of 500 | Emet
# Repeat city, retrying
# Processing Record 152 of 500 | Sibolga
# Processing Record 153 of 500 | Huarmey
# Processing Record 154 of 500 | Hithadhoo
# Repeat city, retrying
# Processing Record 155 of 500 | Changli
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 156 of 500 | Clyde River
# Processing Record 157 of 500 | Hobart
# Repeat city, retrying
# illoqqortoormiut not found, retrying
# Processing Record 158 of 500 | Lavrentiya
# qui nhon not found, retrying
# Processing Record 159 of 500 | Clovis
# Processing Record 160 of 500 | Almaznyy
# Repeat city, retrying
# Repeat city, retrying
# vaitupu not found, retrying
# Processing Record 161 of 500 | Castro
# Repeat city, retrying
# Processing Record 162 of 500 | Faanui
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 163 of 500 | Bereda
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 164 of 500 | Belaya Gora
# Processing Record 165 of 500 | Tonota
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 166 of 500 | Walvis Bay
# Repeat city, retrying
# Processing Record 167 of 500 | Dwarka
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 168 of 500 | Wiang Sa
# Repeat city, retrying
# Processing Record 169 of 500 | Carnarvon
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 170 of 500 | Westport
# Processing Record 171 of 500 | Srednekolymsk
# Repeat city, retrying
# Processing Record 172 of 500 | Hambantota
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 173 of 500 | Vanimo
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 174 of 500 | Yangjiang
# Processing Record 175 of 500 | Bressanone
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 176 of 500 | Mariestad
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 177 of 500 | Evensk
# Processing Record 178 of 500 | Nikolskoye
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 179 of 500 | Bathsheba
# Repeat city, retrying
# Processing Record 180 of 500 | Wuhan
# Repeat city, retrying
# Processing Record 181 of 500 | Plock
# Processing Record 182 of 500 | Gotsu
# Processing Record 183 of 500 | Scituate
# Repeat city, retrying
# gorno-chuyskiy not found, retrying
# teluk nibung not found, retrying
# Repeat city, retrying
# Processing Record 184 of 500 | El Cope
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 185 of 500 | Kununurra
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 186 of 500 | Maple Creek
# Repeat city, retrying
# Processing Record 187 of 500 | Ishigaki
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 188 of 500 | Rio Grande
# Processing Record 189 of 500 | Houma
# Processing Record 190 of 500 | Zvishavane
# Processing Record 191 of 500 | Flinders
# Repeat city, retrying
# Processing Record 192 of 500 | Mehamn
# Processing Record 193 of 500 | Turayf
# Processing Record 194 of 500 | Shimoda
# barentsburg not found, retrying
# Processing Record 195 of 500 | Ekangala
# Processing Record 196 of 500 | Vao
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 197 of 500 | Liaocheng
# Repeat city, retrying
# Processing Record 198 of 500 | Terrace Bay
# Processing Record 199 of 500 | Sitka
# Repeat city, retrying
# Processing Record 200 of 500 | Moose Factory
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 201 of 500 | Yenagoa
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 202 of 500 | Ahuimanu
# Processing Record 203 of 500 | Longyearbyen
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 204 of 500 | Sao Miguel do Araguaia
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 205 of 500 | Taoudenni
# Processing Record 206 of 500 | College
# Repeat city, retrying
# Processing Record 207 of 500 | Skibbereen
# Processing Record 208 of 500 | Vardo
# mys shmidta not found, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 209 of 500 | Arraial do Cabo
# Processing Record 210 of 500 | Mahajanga
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 211 of 500 | Margate
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 212 of 500 | Lafiagi
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 213 of 500 | Iralaya
# Processing Record 214 of 500 | Airai
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 215 of 500 | Zhifang
# Processing Record 216 of 500 | Mehtar Lam
# Repeat city, retrying
# Processing Record 217 of 500 | Bubaque
# Repeat city, retrying
# Processing Record 218 of 500 | Sao Paulo de Olivenca
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 219 of 500 | Akcakoca
# Processing Record 220 of 500 | Nouadhibou
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 221 of 500 | Byron Bay
# Processing Record 222 of 500 | Coos Bay
# Repeat city, retrying
# Processing Record 223 of 500 | Ygatimi
# Repeat city, retrying
# Processing Record 224 of 500 | Puri
# ndele not found, retrying
# Processing Record 225 of 500 | Ayagoz
# Repeat city, retrying
# Repeat city, retrying
# nizhneyansk not found, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 226 of 500 | Madaoua
# Repeat city, retrying
# Processing Record 227 of 500 | Prienai
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 228 of 500 | Qostanay
# Processing Record 229 of 500 | Zelenets
# Processing Record 230 of 500 | Redlands
# Processing Record 231 of 500 | Balikpapan
# Processing Record 232 of 500 | Ovalle
# Processing Record 233 of 500 | Natchitoches
# Processing Record 234 of 500 | Broken Hill
# Processing Record 235 of 500 | Bambous Virieux
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 236 of 500 | Jiayuguan
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 237 of 500 | San Juan
# Processing Record 238 of 500 | Huntsville
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 239 of 500 | Punta Alta
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# ust-kamchatsk not found, retrying
# Repeat city, retrying
# Processing Record 240 of 500 | Tiksi
# Processing Record 241 of 500 | Sao Jose da Coroa Grande
# grand centre not found, retrying
# bengkulu not found, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 242 of 500 | Platteville
# Processing Record 243 of 500 | Leningradskiy
# Processing Record 244 of 500 | Tambo
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 245 of 500 | Saint-Joseph
# Repeat city, retrying
# Processing Record 246 of 500 | Isangel
# Processing Record 247 of 500 | Zeya
# Processing Record 248 of 500 | Aklavik
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 249 of 500 | Cidreira
# Processing Record 250 of 500 | Samarai
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# haibowan not found, retrying
# Repeat city, retrying
# Processing Record 251 of 500 | Prieska
# Processing Record 252 of 500 | Chokurdakh
# Repeat city, retrying
# rungata not found, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 253 of 500 | Aguimes
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 254 of 500 | Saskylakh
# Processing Record 255 of 500 | Ahipara
# Repeat city, retrying
# Processing Record 256 of 500 | Pilibanga
# Repeat city, retrying
# Repeat city, retrying
# bolshiye uki not found, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 257 of 500 | Le Port
# Processing Record 258 of 500 | Ternate
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 259 of 500 | Finschhafen
# Processing Record 260 of 500 | Saint-Francois
# Processing Record 261 of 500 | Surt
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 262 of 500 | Dedza
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# louisbourg not found, retrying
# Repeat city, retrying
# bairiki not found, retrying
# Repeat city, retrying
# Processing Record 263 of 500 | Xinxiang
# Processing Record 264 of 500 | Touros
# Processing Record 265 of 500 | Sao Joao da Barra
# marcona not found, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 266 of 500 | Cayenne
# Repeat city, retrying
# Processing Record 267 of 500 | Balanesti
# Processing Record 268 of 500 | Beringovskiy
# Processing Record 269 of 500 | Sobolevo
# a not found, retrying
# Processing Record 270 of 500 | Vangaindrano
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 271 of 500 | Alofi
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 272 of 500 | Hamilton
# Processing Record 273 of 500 | Winneba
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 274 of 500 | Epe
# Repeat city, retrying
# hunza not found, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 275 of 500 | Khatanga
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 276 of 500 | Buala
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 277 of 500 | Vallenar
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 278 of 500 | Roald
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 279 of 500 | Surskoye
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 280 of 500 | San Felipe
# Repeat city, retrying
# Processing Record 281 of 500 | Avarua
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 282 of 500 | Port Blair
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 283 of 500 | Taos
# Repeat city, retrying
# Processing Record 284 of 500 | Salalah
# Processing Record 285 of 500 | Boa Vista
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# karaul not found, retrying
# Processing Record 286 of 500 | Lipin Bor
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 287 of 500 | Grindavik
# Repeat city, retrying
# Processing Record 288 of 500 | Ukiah
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 289 of 500 | Bakchar
# Repeat city, retrying
# Processing Record 290 of 500 | Mareeba
# Processing Record 291 of 500 | Maunabo
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# ngukurr not found, retrying
# Repeat city, retrying
# Repeat city, retrying
# korla not found, retrying
# Processing Record 292 of 500 | Plouzane
# Repeat city, retrying
# Processing Record 293 of 500 | Diamantino
# Processing Record 294 of 500 | Kavaratti
# Processing Record 295 of 500 | Ust-Nera
# Repeat city, retrying
# Processing Record 296 of 500 | Camacha
# Repeat city, retrying
# Processing Record 297 of 500 | Mao
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 298 of 500 | Naica
# saleaula not found, retrying
# Processing Record 299 of 500 | Maamba
# Processing Record 300 of 500 | Sao Felix do Xingu
# Processing Record 301 of 500 | Otukpo
# Repeat city, retrying
# Processing Record 302 of 500 | Perpignan
# Processing Record 303 of 500 | Klaksvik
# Processing Record 304 of 500 | Loreto
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 305 of 500 | Nesbyen
# Repeat city, retrying
# grand river south east not found, retrying
# Repeat city, retrying
# Processing Record 306 of 500 | Kearney
# Processing Record 307 of 500 | Fort Nelson
# sakakah not found, retrying
# Processing Record 308 of 500 | Berlevag
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 309 of 500 | San Ignacio
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 310 of 500 | Sumbawanga
# Processing Record 311 of 500 | Saint George
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 312 of 500 | Pangnirtung
# Processing Record 313 of 500 | Christchurch
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 314 of 500 | Tancitaro
# Repeat city, retrying
# Processing Record 315 of 500 | Nantucket
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 316 of 500 | Ferme-Neuve
# Processing Record 317 of 500 | Rawson
# Processing Record 318 of 500 | Dhidhdhoo
# Repeat city, retrying
# uroteppa not found, retrying
# Processing Record 319 of 500 | Uvira
# Repeat city, retrying
# Processing Record 320 of 500 | Buluang
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 321 of 500 | Manavalakurichi
# Processing Record 322 of 500 | Sinj
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 323 of 500 | Mahebourg
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 324 of 500 | Lowestoft
# Processing Record 325 of 500 | Ranong
# Processing Record 326 of 500 | Yar-Sale
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 327 of 500 | Honiara
# Processing Record 328 of 500 | Puerto Carreno
# Repeat city, retrying
# Processing Record 329 of 500 | Santa Cruz del Norte
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 330 of 500 | Sambava
# Processing Record 331 of 500 | Piranhas
# Processing Record 332 of 500 | Vysokogornyy
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# ambodifototra not found, retrying
# Processing Record 333 of 500 | Przasnysz
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 334 of 500 | Egvekinot
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 335 of 500 | Belyy Yar
# Processing Record 336 of 500 | Ambilobe
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 337 of 500 | Warri
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 338 of 500 | Hovd
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 339 of 500 | Barcelos
# Processing Record 340 of 500 | Penzance
# eskasem not found, retrying
# Repeat city, retrying
# Processing Record 341 of 500 | Eyl
# Repeat city, retrying
# Processing Record 342 of 500 | Hanstholm
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 343 of 500 | Bodden Town
# Processing Record 344 of 500 | Richards Bay
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 345 of 500 | Whitehorse
# Processing Record 346 of 500 | Suruc
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 347 of 500 | Beyneu
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 348 of 500 | Geraldton
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 349 of 500 | Sudak
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 350 of 500 | Qinhuangdao
# Processing Record 351 of 500 | Gisborne
# Processing Record 352 of 500 | Gamba
# Processing Record 353 of 500 | Georgetown
# Repeat city, retrying
# Processing Record 354 of 500 | Verkhnevilyuysk
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 355 of 500 | Vila Franca do Campo
# Repeat city, retrying
# Processing Record 356 of 500 | Chililabombwe
# hvammstangi not found, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 357 of 500 | Paamiut
# Processing Record 358 of 500 | Kamaishi
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 359 of 500 | Emmett
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 360 of 500 | Pareora
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 361 of 500 | Oudtshoorn
# Processing Record 362 of 500 | Najran
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 363 of 500 | Hillsboro
# Processing Record 364 of 500 | Winnemucca
# Repeat city, retrying
# Processing Record 365 of 500 | Gillette
# Processing Record 366 of 500 | Svetlogorsk
# Processing Record 367 of 500 | Vanavara
# Processing Record 368 of 500 | Yeppoon
# Repeat city, retrying
# Processing Record 369 of 500 | Zhuhai
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 370 of 500 | Yaan
# Repeat city, retrying
# Repeat city, retrying
# kamenskoye not found, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 371 of 500 | Wuda
# Processing Record 372 of 500 | Piacabucu
# Repeat city, retrying
# Repeat city, retrying
# bolungarvik not found, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 373 of 500 | Weligama
# Processing Record 374 of 500 | High Level
# Processing Record 375 of 500 | Chumikan
# Processing Record 376 of 500 | Glazov
# Processing Record 377 of 500 | Saint-Denis
# Repeat city, retrying
# Processing Record 378 of 500 | Riyadh
# Processing Record 379 of 500 | Dillingen
# Processing Record 380 of 500 | Santa Isabel do Rio Negro
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 381 of 500 | Morehead
# Repeat city, retrying
# Processing Record 382 of 500 | Aginskoye
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 383 of 500 | Broome
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 384 of 500 | Biltine
# Repeat city, retrying
# jinchengjiang not found, retrying
# Processing Record 385 of 500 | Muros
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 386 of 500 | Sulangan
# Repeat city, retrying
# Processing Record 387 of 500 | El Espinal
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 388 of 500 | Miri
# Repeat city, retrying
# Processing Record 389 of 500 | Verkhnyaya Toyma
# Repeat city, retrying
# Processing Record 390 of 500 | Los Llanos de Aridane
# Processing Record 391 of 500 | Takaungu
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 392 of 500 | Manzanillo
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 393 of 500 | Mirabad
# Processing Record 394 of 500 | Morondava
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 395 of 500 | Codrington
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 396 of 500 | Ostrovnoy
# Processing Record 397 of 500 | Mabaruma
# Repeat city, retrying
# Processing Record 398 of 500 | Sao Francisco de Paula
# Repeat city, retrying
# Processing Record 399 of 500 | Chuy
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 400 of 500 | Buraydah
# Processing Record 401 of 500 | Havre-Saint-Pierre
# Processing Record 402 of 500 | Tautira
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 403 of 500 | Rawlins
# Processing Record 404 of 500 | Mount Gambier
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 405 of 500 | Kakonko
# Repeat city, retrying
# mananara not found, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 406 of 500 | Seoul
# Processing Record 407 of 500 | Yamnytsya
# Repeat city, retrying
# urumqi not found, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 408 of 500 | Roblin
# Processing Record 409 of 500 | Conde
# Repeat city, retrying
# Processing Record 410 of 500 | Balakhta
# Processing Record 411 of 500 | Anloga
# Processing Record 412 of 500 | Mega
# Processing Record 413 of 500 | Illela
# Repeat city, retrying
# Processing Record 414 of 500 | Mayo
# Processing Record 415 of 500 | Messina
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# krasnoselkup not found, retrying
# Processing Record 416 of 500 | Acajutla
# pokrovsk-uralskiy not found, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 417 of 500 | Orsha
# Repeat city, retrying
# ust-bolsheretsk not found, retrying
# Processing Record 418 of 500 | Padang
# Repeat city, retrying
# Processing Record 419 of 500 | Pyaozerskiy
# Repeat city, retrying
# belushya guba not found, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 420 of 500 | Temir
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# andevoranto not found, retrying
# Processing Record 421 of 500 | Kyabe
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 422 of 500 | Usinsk
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 423 of 500 | Sakete
# Processing Record 424 of 500 | Fairbanks
# Processing Record 425 of 500 | Williams Lake
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 426 of 500 | Atar
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 427 of 500 | Sioux Lookout
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# varadero not found, retrying
# Processing Record 428 of 500 | Ferrol
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 429 of 500 | Bonavista
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 430 of 500 | Elliot Lake
# Repeat city, retrying
# Processing Record 431 of 500 | Sisimiut
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 432 of 500 | Sinnamary
# Repeat city, retrying
# Processing Record 433 of 500 | San Luis
# Repeat city, retrying
# Repeat city, retrying
# bargal not found, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 434 of 500 | Funadhoo
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 435 of 500 | Tessalit
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 436 of 500 | Fortuna
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 437 of 500 | Uvalde
# Processing Record 438 of 500 | Ancud
# Repeat city, retrying
# Processing Record 439 of 500 | Dekar
# Repeat city, retrying
# Processing Record 440 of 500 | Lanzhou
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# zhanatas not found, retrying
# Repeat city, retrying
# Processing Record 441 of 500 | Madera
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 442 of 500 | Lompoc
# Processing Record 443 of 500 | Turbat
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 444 of 500 | Asarganj
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 445 of 500 | Conceicao do Araguaia
# Processing Record 446 of 500 | Matay
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 447 of 500 | Tias
# Processing Record 448 of 500 | Namatanai
# Repeat city, retrying
# Processing Record 449 of 500 | Alvaraes
# Processing Record 450 of 500 | Seymchan
# Repeat city, retrying
# Processing Record 451 of 500 | San Pedro
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 452 of 500 | Plettenberg Bay
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 453 of 500 | Crotone
# Repeat city, retrying
# Processing Record 454 of 500 | Atambua
# toliary not found, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 455 of 500 | Tiznit
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 456 of 500 | Monrovia
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 457 of 500 | Luderitz
# Processing Record 458 of 500 | Axim
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 459 of 500 | Prado
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 460 of 500 | Fort Stewart
# Repeat city, retrying
# Processing Record 461 of 500 | Havelock
# Repeat city, retrying
# Processing Record 462 of 500 | Hirado
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 463 of 500 | Labytnangi
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 464 of 500 | Hofn
# Processing Record 465 of 500 | Mogadishu
# Repeat city, retrying
# Processing Record 466 of 500 | Koindu
# Repeat city, retrying
# satitoa not found, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 467 of 500 | Gazanjyk
# Processing Record 468 of 500 | Wabana
# Processing Record 469 of 500 | Sevnica
# Processing Record 470 of 500 | Ilheus
# Repeat city, retrying
# Processing Record 471 of 500 | Portland
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 472 of 500 | Zyryanka
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 473 of 500 | Kalmunai
# Processing Record 474 of 500 | Cedar City
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 475 of 500 | Tabou
# Repeat city, retrying
# Processing Record 476 of 500 | Hervey Bay
# Processing Record 477 of 500 | Khani
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 478 of 500 | Barra Patuca
# Repeat city, retrying
# Processing Record 479 of 500 | Beisfjord
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 480 of 500 | Kamloops
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 481 of 500 | Alice
# Repeat city, retrying
# Repeat city, retrying
# tsihombe not found, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# asau not found, retrying
# Repeat city, retrying
# Processing Record 482 of 500 | Chifeng
# Processing Record 483 of 500 | Coquimbo
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 484 of 500 | Saint-Pierre
# Processing Record 485 of 500 | Swan Hill
# Processing Record 486 of 500 | Beloha
# Repeat city, retrying
# Processing Record 487 of 500 | Dillon
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 488 of 500 | Abnub
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 489 of 500 | Vagur
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 490 of 500 | Lorengau
# Repeat city, retrying
# Processing Record 491 of 500 | LaBelle
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# skage not found, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 492 of 500 | Lircay
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 493 of 500 | Itaiba
# aflu not found, retrying
# Processing Record 494 of 500 | Arlit
# Repeat city, retrying
# Repeat city, retrying
# Processing Record 495 of 500 | Maldonado
# Processing Record 496 of 500 | Witu
# Processing Record 497 of 500 | Dongsheng
# Processing Record 498 of 500 | Francisco Sa
# Processing Record 499 of 500 | Sohag
# Processing Record 500 of 500 | Emba

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create a dataframe
cityweather_df = pd.DataFrame(columns=["City","Cloudiness","Country","Date","Humidity","Latitude","Longitude","MaxTemp","WindSpeed"])
for citydata in city_jsons:
    cityweather_df.loc[len(cityweather_df)] = [citydata['name'], citydata['clouds']['all'], citydata['sys']['country'], citydata['dt'], citydata['main']['humidity'], citydata['coord']['lat'], citydata['coord']['lon'], citydata['main']['temp_max']-273.15, citydata['wind']['speed']]

cityweather_df.set_index('City',inplace=True)
cityweather_df.to_csv("City Weather Data.csv",index=False)
cityweather_df.count()
# Out:
# Cloudiness    500
# Country       500
# Date          500
# Humidity      500
# Latitude      500
# Longitude     500
# MaxTemp       500
# WindSpeed     500
# dtype: int64

# %%
cityweather_df.head()
# Out:
#              Cloudiness Country        Date Humidity  Latitude  Longitude  \
# City
# Launceston           75      AU  1553920856       38    -41.43     147.14
# Puerto Ayora          8      EC  1553919308       89     -0.74     -90.35
# Saldanha              8      PT  1553920824       79     41.42      -6.55
# Jamestown            20      AU  1553920796       44    -33.21     138.60
# Victoria             75      BN  1553918400       70      5.28     115.24
#
#               MaxTemp  WindSpeed
# City
# Launceston     18.330       6.20
# Puerto Ayora   25.560       1.79
# Saldanha        0.824       0.87
# Jamestown      17.174       7.37
# Victoria       32.000       2.60

# %%
from datetime import datetime
date_read = datetime.fromtimestamp(cityweather_df['Date'].max()).strftime('%Y-%m-%d')
#not sure how best to pull date string. I chose the max timestamp, aka latest time.
#If this was a much smaller dataset and had only cities that did not report often, the date could be problematic
#Even still, most recent data's date isn't really wrong either.
# Out:
# 2019-03-29

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
fig,ax1 = plt.subplots()
ax1.scatter(cityweather_df['Latitude'],cityweather_df['MaxTemp'],alpha=0.5)
ax1.grid(axis="both")
ax1.set_xlim(-90,90)
ax1.set_title(f"Max Temp vs Latitude ({date_read})")
ax1.set_xlabel("Latitude")
ax1.set_ylabel("Max Temp (Celcius)")

ax2 = ax1.twinx()
ax2.set_ylabel("Max Temp (Fahrenheit)")
mini,maxi = ax1.get_ylim()
ax2.set_ylim(9/5*mini+32,9/5*maxi+32)
plt.savefig("Temp vs Latitude.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#To be honest, for THIS case, I think having the independent variable (latitude) on the y axis makes more sense
#if only because everyone associates latitude with the map and it makes more intuitive sense to think going up and down the
#y-axis equates to going north or south in the world.

fig,ax1 = plt.subplots()
ax1.scatter(cityweather_df['MaxTemp'],cityweather_df['Latitude'],alpha=0.5)
ax1.grid(axis="both")
ax1.set_ylim(-90,90)
ax1.set_title(f"Max Temp vs Latitude ({date_read})")
ax1.set_ylabel("Latitude")
ax1.set_xlabel("Max Temp (Celcius)")

ax2 = ax1.twiny()
ax2.set_xlabel("Max Temp (Fahrenheit)")
mini,maxi = ax1.get_xlim()
ax2.set_xlim(9/5*mini+32,9/5*maxi+32)
plt.savefig("Temp vs Latitude (rot).png",bbox_inches="tight")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# As expected, Temperature is highest near the equator. It also falls off as you increase in Latitude either direction
#It looks like there is far more data in the northern hemisphere than southern

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(cityweather_df['Latitude'],cityweather_df['Humidity'],alpha=0.5)
plt.grid(axis="both")
plt.xlim(-90,90)
plt.title(f"Humidity vs Latitude ({date_read})")
plt.xlabel("Latitude")
plt.ylim(0,105)
plt.ylabel("Humidity (%)")
plt.savefig("Humidity vs Latitude.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.scatter(cityweather_df['Humidity'],cityweather_df['Latitude'],alpha=0.5)
plt.grid(axis="both")
plt.ylim(-90,90)
plt.xlim(0,102)
plt.title(f"Humidity vs Latitude ({date_read})")
plt.ylabel("Latitude")
plt.xlabel("Humidity (%)")
plt.savefig("Humidity vs Latitude (rot).png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Not really a good trend can be seen from this IMO.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(cityweather_df['Latitude'],cityweather_df['Cloudiness'],alpha=0.5)
plt.grid(axis="both")
plt.xlim(-90,90)
plt.title(f"Cloudiness vs Latitude ({date_read})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("Cloudiness vs Latitude.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.scatter(cityweather_df['Cloudiness'],cityweather_df['Latitude'],alpha=0.5)
plt.grid(axis="both")
plt.ylim(-90,90)
plt.title(f"Cloudiness vs Latitude ({date_read})")
plt.ylabel("Latitude")
plt.xlabel("Cloudiness (%)")
plt.savefig("Cloudiness vs Latitude (rot).png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Trend...Cloudiness doesn't seem to care much about Latitude. It looks like cloudiness is reported in discrete values though
#because it looks like there is weird clustering at certain values - 20%, 40%, 75% for example. To check:
cityweather_df['Cloudiness'].value_counts().sort_values(ascending=False)
#Some make sense like 90 75 20 40, 0, 100, 80, but I have no idea why numbers like 92, 88, 68, 1, 76 are so common.

#cloud cover is measured in "oktas" which is just how many eighths of sky is covered by cloud.
# explains 12 (1/8=12.5), and 88 (7/8=87.5) but others remain a mystery
# Out:
# 0      141
# 90      42
# 75      42
# 20      36
# 40      31
# 92      25
# 88      20
# 1       20
# 68      19
# 8       17
# 76      17
# 44      15
# 32      11
# 12      11
# 64      10
# 24       9
# 36       9
# 80       8
# 48       5
# 56       5
# 5        4
# 100      3
# Name: Cloudiness, dtype: int64

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig,ax1 = plt.subplots()
ax1.scatter(cityweather_df['Latitude'],cityweather_df['WindSpeed'],alpha=0.5)
ax1.grid(axis="both")
ax1.set_xlim(-90,90)
ax1.set_title(f"Wind Speed vs Latitude ({date_read})")
ax1.set_xlabel("Latitude")
ax1.set_ylabel("Wind Speed (m/s)")

ax2 = ax1.twinx()
mini,maxi = ax1.get_ylim()

ax2.set_ylim(mini/1609.34*3600,maxi/1609.34*3600)
ax2.set_ylabel("Wind Speed(mph)")

plt.savefig("WindSpeed vs Latitude.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
fig,ax1 = plt.subplots()
ax1.scatter(cityweather_df['WindSpeed'],cityweather_df['Latitude'],alpha=0.5)
ax1.grid(axis="both")
ax1.set_ylim(-90,90)
ax1.set_title(f"Wind Speed vs Latitude ({date_read})")
ax1.set_ylabel("Latitude")
ax1.set_xlabel("Wind Speed (m/s)")

ax2 = ax1.twiny()
mini,maxi = ax1.get_xlim()

ax2.set_xlim(mini/1609.34*3600,maxi/1609.34*3600)
ax2.set_xlabel("Wind Speed(mph)")
plt.savefig("WindSpeed vs Latitude (rot).png",bbox_inches="tight")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Generally wind speed also doesn't seem to care about latitude much. Fairly evenly spread at 0-10 m/s speeds all the way
#from -50 to +80 latitude

# %%
#for fun - plotting every city, latitude vs longitude, with temperature as color
plt.figure(figsize=(10,6))
plt.scatter(cityweather_df['Longitude'],cityweather_df['Latitude'],c=cityweather_df['MaxTemp'],cmap='rainbow')
plt.hlines(0,-180,180)
cbar = plt.colorbar()
cbar.set_label('Temperature (Celcius)')
plt.ylim(-90,90)
plt.xlim(-180,180)
plt.title(f"Temp vs Latitude and Longitude ({date_read})")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.savefig("Temperature map.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#testing openweathermap's bbox function to grab a bunch of cities within a box(box of -180,-90 to 180,90, AKA the whole world)
#it does not state how many cities it can return.
mass_weather_dump = requests.get(f"http://api.openweathermap.org/data/2.5/box/city?bbox=-180,-90,180,90&APPID={api_key}").json()
# Out:
# 469

# %%
mass_weather_dump_df = pd.DataFrame(columns=["Name","Lat","Long","Temp","Time"])
for eachcity in mass_weather_dump['list']:
    mass_weather_dump_df.loc[len(mass_weather_dump_df)] = [eachcity['name'],eachcity['coord']['Lat'],eachcity['coord']['Lon'],eachcity['main']['temp_max'],eachcity['dt']]

mass_dump_date_read = datetime.fromtimestamp(mass_weather_dump_df['Time'].max()).strftime('%Y-%m-%d')

plt.figure(figsize=(10,6))
plt.scatter(mass_weather_dump_df['Long'],mass_weather_dump_df['Lat'],c=mass_weather_dump_df["Temp"],cmap='rainbow')
cbar = plt.colorbar()
cbar.set_label("Temp (C)")
plt.title(f"Temp vs Latitude and Longitude ({mass_dump_date_read})")
plt.ylim(-90,90)
plt.xlim(-180,180)
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.hlines(0,-180,180)
plt.savefig("Temperature Map (method2).png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
